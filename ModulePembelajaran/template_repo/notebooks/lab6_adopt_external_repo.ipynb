# %% [markdown]
# # Lab 6 · Adopsi Repo Eksternal
#
# Terkait: **Bab 06 · Adopsi Repository Riset**
#
# ## Skenario
# Clone `pytorch/vision` (atau repo riset lain yang disetujui pembimbing), pelajari struktur reference implementation untuk classification (`references/classification/`), dan adaptasi *satu* komponen ke template repo kamu (contoh: augmentasi pipeline atau scheduler).
#
# ## Tujuan
# 1. Terapkan urutan baca luar-ke-dalam yang dibahas di Bab 06.
# 2. Tulis *15-minute map* repo asing di sel markdown.
# 3. Lakukan 3-level smoke test pada kode asing.
# 4. Porting 1 komponen kecil ke template repo; patch minimal-invasif.
#
# ## Checklist
# - [ ] Peta struktur folder + entry point tercatat.
# - [ ] Smoke test L1 (import), L2 (forward), L3 (1 iteration) lulus di kode asing.
# - [ ] Komponen yang diport dapat dipanggil dari `src/`.
# - [ ] Commit dengan pesan jelas: "feat: port RandAugment from torchvision/references".

# %% [markdown]
# ## 1. Clone + eksplorasi struktur

# %%
# TODO:
# !git clone --depth 1 https://github.com/pytorch/vision external/vision
# Lalu baca: external/vision/references/classification/train.py dan presets.py

# %% [markdown]
# ## 2. 15-minute map (TODO isi)
#
# ```
# external/vision/references/classification/
# ├── train.py          (entry point: main() di bawah)
# ├── presets.py        (Classification presets: augmentasi)
# ├── transforms.py     (TrivialAugmentWide, RandAugment, MixUp)
# ├── utils.py          (distributed helpers, metric loggers)
# └── ...
# ```
#
# Apa yang kamu adaptasi? Tulis kandidat + justifikasi singkat.

# %% [markdown]
# ## 3. Smoke test

# %%
# L1: import tanpa error
# L2: forward pass dengan dummy tensor
# L3: satu iterasi training dengan DataLoader dummy

# %% [markdown]
# ## 4. Porting komponen

# %%
# TODO: salin/adaptasi ke src/augmentations.py (file baru).
# Jaga supaya config YAML dapat mengaktifkan dengan key baru, defaultnya False.

# %% [markdown]
# ## 5. Refleksi (TODO)
#
# 1. Berapa lama total: clone → map → port? Apakah < 3 jam?
# 2. Apa satu pola kode dari repo asing yang kamu adopsi ke gaya tulisanmu sendiri?
# 3. Apa bagian yang *tidak* kamu port, meski menarik — kenapa (scope, dependency, kompleksitas)?
