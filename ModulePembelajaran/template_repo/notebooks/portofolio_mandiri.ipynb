# %% [markdown]
# # Portofolio Mandiri
#
# | | |
# |---|---|
# | **Nama** | *(isi nama lengkap)* |
# | **NIM** | *(isi NIM)* |
# | **Program Studi** | *(isi prodi)* |
# | **Semester** | *(isi semester dan tahun)* |
# | **Topik riset / minat utama** | *(satu kalimat tentang arah riset atau skill yang ingin dikembangkan)* |
#
# ---
#
# Notebook ini adalah catatan perjalanan eksplorasi mandiri selama satu semester. Setiap entri diisi setelah menyelesaikan Komponen Mandiri di bab terkait, *sebelum* sesi presentasi dimulai.
#
# **Cara menggunakan notebook ini:**
# - Isi satu entri per pekan; jangan menunda.
# - Bagian *Koneksi ke pekan sebelumnya* adalah bagian terpenting  -  ia memaksa Anda melihat pola dalam belajar Anda sendiri.
# - Jangan menghapus atau mempercantik entri lama. Entri jujur tentang kegagalan lebih bernilai dari entri yang dibuat-buat bagus.
# - Pada akhir Pekan 12, isi sel *Refleksi Portofolio* di bagian bawah.
#
# Template entri lengkap dan panduan presentasi 10 menit ada di `12_Lampiran.md` bagian C.6 dan C.7.

# %% [markdown]
# ---
#
# ## Entri Pekan 4 - Bab 02: Ide ke Eksperimen
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Ini adalah entri pertama  -  tulis motivasi awal: mengapa jalur ini dipilih, dan apa yang Anda harapkan ditemukan dari eksplorasi mandiri sepanjang semester ini.)*

# %% [markdown]
# ---
#
# ## Entri Pekan 5 - Bab 03: Eksperimen Reproduksibel
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 4? Apakah cara merancang sesuatu berubah setelah Anda mempraktikkan reproduksibilitas?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 7 - Bab 04: Validasi Data
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 5? Apakah temuan tentang data mengubah cara Anda memandang eksperimen yang sudah dijalankan di Pekan 4 atau 5?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 8 - Bab 05: AI Tools Sebagai Pendukung
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 7? Apakah cara Anda memakai LLM berubah dibanding cara Anda merancang eksperimen di awal semester?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 9 - Bab 06: Adopsi Repo Riset
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 8? Apakah Anda melihat pola yang sama antara cara repo riset eksternal distruktur dengan cara Anda sendiri menulis kode?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 10 - Bab 07: Alat Pendukung Ringan
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 9? Apa yang bisa Anda visualisasikan sekarang yang tidak mungkin divisualisasikan di awal semester?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 11 - Bab 08: Platform & Tool Baru
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 10? Bagaimana pengalaman *pelatihan jarak jauh* ini mengubah asumsi tentang reproduksibilitas yang Anda bangun sejak Pekan 5?)*

# %% [markdown]
# ---
#
# ## Entri Pekan 12 - Bab 09: Pengembangan Mandiri
#
# **Tanggal:** YYYY-MM-DD
# **Jalur yang dipilih:** A - Implementasi / B - Analisis / C - Desain *(hapus yang tidak dipilih)*
# **Alasan memilih jalur ini:** *(Satu kalimat: apa yang ingin Anda pelajari atau buktikan.)*
#
# ### Setup
#
# *(Apa yang dikerjakan, tool/dataset/config yang dipakai, dan berapa lama.)*
#
# ### Temuan
#
# *(Apa yang ditemukan. Sertakan angka, grafik, atau output kunci. Hindari "saya berhasil" tanpa angka.)*
#
# ### Kejutan
#
# *(Apa yang tidak sesuai ekspektasi. Jika semua sesuai ekspektasi, tanyakan pada diri sendiri apakah ekspektasi awalnya sudah cukup spesifik.)*
#
# ### Yang Akan Diubah
#
# *(Jika mengulang eksperimen ini minggu depan, satu hal yang akan dilakukan berbeda dan mengapa.)*
#
# ### Koneksi ke Pekan Sebelumnya
#
# *(Bagaimana pekerjaan pekan ini terhubung atau bertentangan dengan pekerjaan Pekan 11? Setelah 8 minggu eksplorasi mandiri, apa pertanyaan riset yang paling konsisten muncul dalam catatan Anda?)*

# %% [markdown]
# ---
#
# ## Refleksi Portofolio (Akhir Semester)
#
# > Isi sel ini setelah semua 8 entri selesai, sebelum presentasi *highlight* portofolio di awal Pekan 13.
#
# ### Trajektori Belajar
#
# *(Satu paragraf: lihat kembali semua 8 entri. Apa pola yang Anda lihat? Apakah ada jalur yang selalu Anda pilih atau hindari, dan mengapa? Apa yang berubah dari cara Anda mendekati masalah di Pekan 4 vs Pekan 12?)*
#
# ### Entri yang Paling Informatif
#
# *(Pilih satu entri yang hasilnya paling mengejutkan atau paling mengubah cara berpikir Anda. Jelaskan mengapa.)*
#
# ### Pertanyaan Terbuka
#
# *(Satu pertanyaan riset yang muncul dari keseluruhan portofolio ini  -  pertanyaan yang belum terjawab dan ingin Anda kejar setelah kelas ini selesai.)*
#
# ### Untuk Presentasi Pekan 13
#
# *(Pilih 2-3 *highlight* dari 8 entri untuk dipresentasikan: satu temuan terkuat, satu kejutan paling berharga, satu koneksi lintas pekan yang paling menarik. Tulis di sini sebagai catatan persiapan.)*
