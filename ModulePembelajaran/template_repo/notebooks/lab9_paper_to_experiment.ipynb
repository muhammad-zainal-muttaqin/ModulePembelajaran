# %% [markdown]
# # Lab 9 · Paper to Experiment
#
# Terkait: **Bab 09 · Pengembangan Diri Berkelanjutan**
#
# ## Tujuan
# 1. Pilih 1 paper arXiv <= 7 hari terakhir di bidang yang kamu minati.
# 2. Baca putaran 1 + 2; tulis catatan format Bab 09.
# 3. 5 Whys: turunkan minat jadi 1 pertanyaan yang dapat diuji di template repo.
# 4. Pre-registration lengkap (5 bagian) SEBELUM tulis kode eksperimen.
# 5. Eksekusi eksperimen (<=3 jam training) dengan 3 seed.
# 6. Laporan 1 halaman: hasil vs pre-reg, deviasi, pertanyaan berikut.
#
# ## Deliverable
# - `docs/papers/<slug>.md` - catatan paper
# - `docs/preregs/<date>_<slug>.md` - pre-registration
# - `docs/experiments/<slug>_report.md` - experiment report 1 halaman
# - Update `docs/journal.md` dengan pertanyaan baru yang muncul

# %% [markdown]
# ## 1. Filter arXiv
#
# TODO: sebutkan query yang dipakai (kategori + keyword), jumlah judul yang muncul, top 5 abstrak yang kamu baca, paper yang kamu pilih.

# %% [markdown]
# ## 2. Catatan paper (TODO isi)
#
# Gunakan template dari Lampiran §C.5 di `docs/papers/<slug>.md`. Tempel link file di sini.

# %% [markdown]
# ## 3. 5 Whys (TODO isi)
#
# Tulis 5 langkah turunkan dari minat → pertanyaan spesifik.

# %% [markdown]
# ## 4. Pre-Registration (TODO)
#
# Simpan ke `docs/preregs/<date>_<slug>.md` sesuai template Lampiran §C.1. Tanggal file HARUS lebih tua dari commit pertama kode eksperimen - verifikasi dengan `git log --follow <file>`.

# %% [markdown]
# ## 5. Eksekusi

# %%
# TODO: jalankan eksperimen - 3 seed, cukup untuk menjawab hipotesis.
# Bila butuh library/metode baru, pakai pola Bab 5 (LLM assist + verifikasi).

# %% [markdown]
# ## 6. Laporan singkat (TODO)
#
# Struktur di `docs/experiments/<slug>_report.md`:
# 1. Hipotesis (salin dari pre-reg).
# 2. Protokol aktual (catat deviasi bila ada).
# 3. Hasil (tabel 3 seed + μ ± σ).
# 4. Verdict: terkonfirmasi / tidak / inconclusive.
# 5. Pertanyaan berikutnya.

# %% [markdown]
# ## 7. Refleksi
#
# 1. Apa yang paling sulit: memilih paper, memformulasikan pertanyaan, atau menjaga pre-reg?
# 2. Di mana kamu paling tergoda menyimpang dari pre-reg?
# 3. Satu kalimat komitmen belajar mingguan setelah kelas selesai - yang realistis dan menantang.
