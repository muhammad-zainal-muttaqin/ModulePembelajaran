# %% [markdown]
# # Lab W10: Paper to Code
#
# Terkait: **Bab 10 · Paper Reading & Implementation**
#
# ## Tujuan
# 1. Pilih 1 paper yang cocok untuk implementasi kecil: Focal Loss, DropBlock, atau paper lain yang disetujui dosen.
# 2. Identifikasi status publikasi paper: arXiv preprint, workshop, conference, atau journal.
# 3. Baca paper dengan metode three-pass dan tulis catatan teknis.
# 4. Terjemahkan core contribution menjadi rencana paper-to-code: input/output tensor, komponen essential, dan batas scope.
# 5. Implementasikan core method pada dataset kecil atau toy setup.
# 6. Jalankan smoke test untuk memastikan implementasi benar secara mekanis.
# 7. Jalankan parity check sederhana atau satu ablation kecil.
# 8. Tulis laporan 1 halaman tentang hasil, gap, dan bagian paper yang ternyata sulit diterjemahkan ke kode.
#
# ## Luaran
# - `docs/papers/<slug>.md` - catatan three-pass dan rencana implementasi minimal.
# - Implementasi core method di `src/` atau notebook ini.
# - Bukti smoke test dan hasil ablation/parity check.
# - `docs/experiments/<slug>_report.md` - experiment report 1 halaman.

# %% [markdown]
# ## 1. Kurasi Paper dan Status Publikasi
#
# TODO:
# - Sebutkan query yang dipakai: kategori arXiv, keyword, dan rentang tahun bila ada.
# - Catat jumlah judul yang muncul dan top 5 abstrak yang kamu baca.
# - Pilih 1 paper untuk diimplementasikan.
# - Tulis status publikasi paper: arXiv preprint, workshop, conference, atau journal.
# - Jika paper berasal dari arXiv, jelaskan apakah ada versi peer-reviewed dan versi arXiv mana yang kamu baca.
#
# Catatan: arXiv adalah alat akses dan radar ide, bukan sumber otoritas final. Klaim paper tetap harus dicek lewat setup eksperimen, baseline, ablation, dan kode.

# %% [markdown]
# ## 2. Catatan Three-Pass (TODO isi)
#
# Gunakan template Bab W10 §2.4 di `docs/papers/<slug>.md`. Minimal isi:
# 1. TL;DR.
# 2. Metode dan rumus/sketsa penting.
# 3. Bukti: dataset, metrik, hasil utama.
# 4. Pertanyaan/kritik teknis.
# 5. Rencana implementasi minimal.
#
# Tempel link file di sini.

# %% [markdown]
# ## 3. Paper-to-Code Plan (TODO isi)
#
# Tulis rencana implementasi sebelum coding:
# 1. Core contribution dalam 1 kalimat.
# 2. Input tensor dan output tensor.
# 3. Komponen essential yang wajib ada.
# 4. Engineering detail yang sengaja tidak diimplementasikan.
# 5. Dataset kecil/toy setup yang dipakai.
# 6. Ablation atau parity check yang akan dijalankan.

# %% [markdown]
# ## 4. Implementasi dan Smoke Test (TODO)
#
# Sebutkan file/fungsi yang akan dibuat atau diubah. Tulis minimal 2 smoke test sebelum menjalankan training penuh.
#
# Contoh smoke test:
# - `gamma=0` pada focal loss harus identik dengan cross-entropy dalam toleransi numerik.
# - Output shape layer baru harus sama dengan input shape yang dijanjikan paper.
# - Loss harus finite pada batch kecil.
# - Forward pass harus berjalan di CPU dan GPU bila tersedia.

# %% [markdown]
# ## 5. Eksekusi

# %%
# TODO: run the minimal implementation and one ablation/parity check.
# Keep the scope small: same model, same dataset split, same metric, one changed variable.
# Save the command/config and the resulting metric table for the report.

# %% [markdown]
# ## 6. Laporan Singkat (TODO)
#
# Struktur di `docs/experiments/<slug>_report.md`:
# 1. Paper dan status publikasi: arXiv/workshop/conference/journal, versi yang dibaca, dan link.
# 2. Core contribution yang diimplementasikan.
# 3. Scope implementasi: apa yang dibuat, apa yang sengaja tidak dibuat.
# 4. Smoke test: test yang dijalankan dan hasilnya.
# 5. Hasil ablation/parity check: tabel metrik, seed/config, dan gap terhadap klaim paper.
# 6. Analisis teknis: bagian paper yang ambigu, detail yang harus dicari di appendix/code, dan pelajaran implementasi.

# %% [markdown]
# ## 7. Refleksi
#
# 1. Apa yang paling sulit saat menerjemahkan paper menjadi kode: notasi, detail implementasi, setup eksperimen, atau debugging?
# 2. Apakah ablation/parity check mendukung klaim paper? Jika tidak, gap teknis apa yang paling mungkin menjelaskannya?
# 3. Setelah memakai arXiv, bukti apa yang membuat kamu lebih percaya atau lebih skeptis terhadap paper ini?
# 4. Skill paper-to-code apa yang perlu kamu latih lagi sebelum W11 dan capstone?
